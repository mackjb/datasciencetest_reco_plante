# %%
from pathlib import Path

# 1. Trouve dynamiquement la racine du projet (contenant .gitignore)
cwd = Path.cwd()
PROJECT_ROOT = next(p for p in (cwd, *cwd.parents) if (p / ".gitignore").exists())

print("PROJECT_ROOT =", PROJECT_ROOT)
# Out:
# PROJECT_ROOT = /Users/mackjb/repository/datasciencetest_reco_plante

# %%
from pathlib import Path
import pandas as pd
import plotly.express as px
import os
from PIL import Image, ImageFilter
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import cv2
from sklearn.cluster import DBSCAN
import albumentations as A

# %%
def resize_and_pad(img, size=(256, 256), fill_color=(0, 0, 0, 0)):
    """
    Redimensionne l'image en gardant le ratio, puis pad pour obtenir une taille exacte size.
    fill_color = noir opaque (0,0,0) pour JPG, ou transparent (0,0,0,0) pour PNG.
    """
    original_size = img.size
    ratio = min(size[0]/original_size[0], size[1]/original_size[1])
    new_size = (int(original_size[0]*ratio), int(original_size[1]*ratio))
    img.resize(size, Image.Resampling.LANCZOS)
    
    # Crée une nouvelle image avec fond noir (ou transparent)
    if img.mode in ('RGBA', 'LA') or (img.mode == 'P' and 'transparency' in img.info):
        new_img = Image.new("RGBA", size, fill_color)
    else:
        new_img = Image.new("RGB", size, fill_color[:3])
    
    paste_pos = ((size[0] - new_size[0]) // 2, (size[1] - new_size[1]) // 2)
    new_img.paste(img, paste_pos)
    return new_img

# %%
from PIL import Image, ImageFilter
import numpy as np
import albumentations as A
import os
from pathlib import Path

# 0) Définition des transforms déterministes
transforms = {
    "rot90":      A.Rotate(limit=(90, 90), p=1.0),
    "rot180":     A.Rotate(limit=(180, 180), p=1.0),
    "flip_h":     A.HorizontalFlip(p=1.0),
    "flip_v":     A.VerticalFlip(p=1.0),
    "shift_scale": A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=0, p=1.0),
}

# 1) Chemins
root_dir  = PROJECT_ROOT/"dataset"/"plantvillage"/"data"/"plantvillage_5images"/"segmented"
clean_dir = PROJECT_ROOT/"dataset"/"plantvillage"/"data"/"plantvillage_clean"/"segmented"
clean_dir.mkdir(parents=True, exist_ok=True)

# 2) Boucle sur chaque image
for subdir, dirs, files in os.walk(root_dir):
    for file in files:
        if not file.lower().endswith(('.jpg','.jpeg','.png')): 
            continue

        src_path = Path(subdir)/file
        rel_path  = src_path.relative_to(root_dir)
        dst_path  = clean_dir/rel_path
        dst_path.parent.mkdir(parents=True, exist_ok=True)

        try:
            with Image.open(src_path) as img:
                # a) Resize & pad → 256×256
                cleaned = resize_and_pad(img, size=(256,256), fill_color=(0,0,0,0))

                # b) Filtre gaussien → lissage
                cleaned = cleaned.filter(ImageFilter.GaussianBlur(radius=1.0))

                # c) Application systématique de chaque transform
                arr = np.array(cleaned)
                for name, tr in transforms.items():
                    aug_arr = tr(image=arr)["image"]
                    aug_img = Image.fromarray(aug_arr)
                    aug_img = resize_and_pad(aug_img, size=(256,256), fill_color=(0,0,0,0))

                    stem, ext = dst_path.stem, dst_path.suffix
                    outp = dst_path.parent/f"{stem}_{name}{ext}"
                    if ext.lower() in ['.jpg','jpeg']:
                        aug_img = aug_img.convert('RGB')
                        aug_img.save(outp, quality=95)
                    else:
                        aug_img.save(outp)
                    # print(f"Saved variant {name}:", outp)

                # d) Sauvegarde de l’image nettoyée d’origine
                if dst_path.suffix.lower() in ['.jpg','jpeg']:
                    cleaned = cleaned.convert('RGB')
                    cleaned.save(dst_path, quality=95)
                else:
                    cleaned.save(dst_path)

        except Exception as e:
            print(f"Erreur sur {src_path}: {e}")

# %%
# # Chemin vers le dossier principal PlantVillage
# # root_dir = PROJECT_ROOT / "dataset" / "plantvillage" / "data" / "plantvillage dataset" / "segmented"
# root_dir = PROJECT_ROOT / "dataset" / "plantvillage" / "data" / "plantvillage_5images" / "segmented"


# # Le dossier destination, prefixé "clean_"
# clean_dir = PROJECT_ROOT / "dataset" / "plantvillage" / "data" / "plantvillage_clean" / "segmented"
# clean_dir.mkdir(parents=True, exist_ok=True)

# for subdir, dirs, files in os.walk(root_dir):
#     for file in files:
#         if file.lower().endswith(('.jpg', '.jpeg', '.png')):
#             src_path = Path(subdir) / file
#             # Chemin relatif par rapport à root_dir
#             rel_path = src_path.relative_to(root_dir)
#             dst_path = clean_dir / rel_path
            
#             # Crée les dossiers parents du fichier de destination si besoin
#             dst_path.parent.mkdir(parents=True, exist_ok=True)
            
#             try:
#                 with Image.open(src_path) as img:
#                     # Redimensionne et pad
#                     new_img = resize_and_pad(img, size=(256, 256), fill_color=(0,0,0,0))
#                     # Sauvegarde en conservant le format (extension)
#                     if dst_path.suffix.lower() in ['.jpg', '.jpeg']:
#                         # Convertir en RGB pour JPEG et enlever alpha
#                         if new_img.mode != 'RGB':
#                             new_img = new_img.convert('RGB')
#                         new_img.save(dst_path, quality=95)
#                     else:
#                         # PNG garde RGBA
#                         new_img.save(dst_path)
#             except Exception as e:
#                 print(f"Erreur sur {src_path}: {e}")

# %%
# # Le filtre gaussien atténue le bruit haute fréquence pour éviter les artefacts visuels et de fausses frontières.
# # Il stabilise les descripteurs d’images (HOG, SIFT…), améliorant leur cohérence et la séparation linéaire par le SVM.
# # En supprimant les détails non pertinents, il réduit la variance du modèle et limite le surapprentissage.
# # C’est un prétraitement standard qui renforce la robustesse du pipeline et facilite la généralisation.


# # Définition du pipeline d’augmentation, on veut étendre notre dataset avec des prises de vue différentes
# augmenter = A.Compose([
#     A.Rotate(limit=90, p=0.5),
#     A.HorizontalFlip(p=0.5),
#     A.VerticalFlip(p=0.5),
#     A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=0, p=0.5)
# ])


# # Chemin vers le dossier principal PlantVillage
# root_dir = PROJECT_ROOT / "dataset" / "plantvillage" / "data" / "plantvillage_5images" / "segmented"

# # Le dossier destination, préfixé "clean_"
# clean_dir = PROJECT_ROOT / "dataset" / "plantvillage" / "data" / "plantvillage_clean" / "segmented"
# clean_dir.mkdir(parents=True, exist_ok=True)

# for subdir, dirs, files in os.walk(root_dir):
#     for file in files:
#         if file.lower().endswith(('.jpg','.jpeg','.png')):
#             src_path = Path(subdir)/file
#             rel_path = src_path.relative_to(root_dir)
#             dst_path = clean_dir/rel_path
#             dst_path.parent.mkdir(parents=True, exist_ok=True)

#             try:
#                 with Image.open(src_path) as img:
#                     # 1) Redimension & pad
#                     new_img = resize_and_pad(img, size=(256,256), fill_color=(0,0,0,0))
#                     # 2) Filtre Gaussien
#                     new_img = new_img.filter(ImageFilter.GaussianBlur(radius=1.0))

#                     # 3) Augmentation via Albumentations
#                     arr = np.array(new_img)
#                     aug = augmenter(image=arr)['image']
#                     aug_img = Image.fromarray(aug)

#                     # on repad pour garantir 256×256
#                     aug_img = resize_and_pad(aug_img, size=(256,256), fill_color=(0,0,0,0))

#                     # nommage : original_suffix.ext
#                     stem, ext = dst_path.stem, dst_path.suffix
#                     aug_path = dst_path.parent / f"{stem}_alb{ext}"
#                     if ext.lower() in ['.jpg','.jpeg']:
#                         aug_img = aug_img.convert('RGB')
#                         aug_img.save(aug_path, quality=95)
#                     else:
#                         aug_img.save(aug_path)
#                     print("Saved augmented image:", aug_path)

#                     # 4) Sauvegarde de l’image originale nettoyée
#                     if dst_path.suffix.lower() in ['.jpg',' .jpeg']:
#                         new_img = new_img.convert('RGB')
#                         new_img.save(dst_path, quality=95)
#                     else:
#                         new_img.save(dst_path)

#             except Exception as e:
#                 print(f"Erreur sur {src_path}: {e}")
# Out:
# /opt/miniconda3/envs/conda_env/lib/python3.11/site-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Strawberry___healthy/00532378-bfb2-4d3b-8b19-903ecc085624___RS_HL 2021_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Strawberry___healthy/02808b3e-ae88-4259-9b2c-f9096db336e4___RS_HL 1827_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Strawberry___healthy/01e591c9-e3e7-4edc-8211-13081f4d5e7a___RS_HL 1979_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Strawberry___healthy/00e9a277-ca5e-4350-95ce-8b2918b69fb9___RS_HL 4667_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Strawberry___healthy/00166615-5e7b-4318-8957-5e50df335ee8___RS_HL 1785_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Grape___Black_rot/003d09ef-e16c-4e8a-badf-847d46cb3dc0___FAM_B.Rot 3184_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Grape___Black_rot/004175d8-dc74-4285-8401-3cc9565730bb___FAM_B.Rot 0626_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Grape___Black_rot/00905d40-bddf-460e-b348-1dbb6a34653b___FAM_B.Rot 0664_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Grape___Black_rot/006efc68-9e46-4168-921c-10ef8065702c___FAM_B.Rot 3470_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Grape___Black_rot/00090b0f-c140-4e77-8d20-d39f67b75fcc___FAM_B.Rot 0376_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Potato___Early_blight/001187a0-57ab-4329-baff-e7246a9edeb0___RS_Early.B 8178_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Potato___Early_blight/0182e991-97f0-4805-a1f7-6e1b4306d518___RS_Early.B 7015_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Potato___Early_blight/00d8f10f-5038-4e0f-bb58-0b885ddc0cc5___RS_Early.B 8722_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Potato___Early_blight/009c8c31-f22d-4ffd-8f16-189c6f06c577___RS_Early.B 7885_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Potato___Early_blight/002a55fb-7a3d-4a3a-aca8-ce2d5ebc6925___RS_Early.B 8170_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Blueberry___healthy/011405e4-a92a-44b6-9f04-10fec28d93f5___RS_HL 2311_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Blueberry___healthy/008c85d0-a954-4127-bd26-861dc8a1e6ff___RS_HL 2431_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Blueberry___healthy/00fee259-67b7-4dd7-8b36-12503bbdba14___RS_HL 2681_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Blueberry___healthy/0137389a-9b78-4a94-afdb-c2b50861f89c___RS_HL 2347_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Blueberry___healthy/013ffdc5-cbd1-4202-b0f1-8fd7c1ffc0b8___RS_HL 5120_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Corn_(maize)___healthy/00665f92-adb0-41eb-bba7-9eeadecfe10e___R.S_HL 8325 copy 2_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Corn_(maize)___healthy/026bd735-b9f4-4eab-86f3-23df15dbec95___R.S_HL 7938 copy_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Corn_(maize)___healthy/00031d74-076e-4aef-b040-e068cd3576eb___R.S_HL 8315 copy 2_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Corn_(maize)___healthy/01c3bf88-d315-42a3-8fa1-fc80a05c97f1___R.S_HL 8189 copy_final_masked_alb.jpg
# Saved augmented image: /Users/mackjb/repository/datasciencetest_reco_plante/dataset/plantvillage/data/plantvillage_clean/segmented/Corn_(maize)